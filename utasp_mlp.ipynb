# %%
import pandas as pd
import numpy as np
import keras

from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Activation
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from IPython.display import display
from collections import OrderedDict

pd.options.display.max_rows = None
pd.options.display.float_format = '{:,.3f}'.format
# Out:
# Using TensorFlow backend.
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
def load_utasp():
    df = pd.read_csv('./2014UTASP.csv')
    utasp_name = df.iloc[:, 0]
    utasp_y = to_categorical(df.iloc[:, 1].values - 1)
    utasp_X = df.iloc[:, 2:].values.astype('float32') / 6
    train_X, test_X, train_y, test_y = train_test_split(utasp_X, np.c_[utasp_name, utasp_y], test_size=0.1, random_state=42)
    train_name = train_y[:, 0]
    train_y = train_y[:, 1:]
    test_name = test_y[:, 0]
    test_y = test_y[:, 1:]
    return (train_X, train_y, train_name), (test_X, test_y, test_name)


def utasp_model():
    model = Sequential()
    model.add(Dense(units=150, activation='relu', input_shape=(33,)))
    model.add(Dense(units=50, activation='relu'))
    model.add(Dense(units=6, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])
    return model

# %%
(train_X, train_y, train_name), (test_X, test_y, test_name) = load_utasp()
model = utasp_model()
model.fit(train_X, train_y, batch_size=30, epochs=20, verbose=0)
pred_y = model.predict(test_X)
label = ['自', '民', '維', '公', '次', '共']

res_df = pd.DataFrame(OrderedDict([('氏名', test_name) ,
                    ('所属', np.vectorize(lambda x: label[x])(np.argmax(test_y, 1))),
                    ('予測', np.vectorize(lambda x: label[x])(np.argmax(pred_y, 1))),
                    (label[0], pred_y[:, 0]),
                    (label[1], pred_y[:, 1]),
                    (label[2], pred_y[:, 2]),
                    (label[3], pred_y[:, 3]),
                    (label[4], pred_y[:, 4]),
                    (label[5], pred_y[:, 5]),
                    ('正誤', np.vectorize(lambda x, y: '◎' if x == y else ' ')(np.argmax(pred_y, 1), np.argmax(test_y, 1)))]))

# %%
display(res_df)
# Out:
#         氏名 所属 予測     自     民     維     公     次     共 正誤
# 0    牧野＝次郎  共  共 0.000 0.009 0.000 0.000 0.000 0.991  ◎
# 1    小浜＝一輝  共  共 0.000 0.005 0.000 0.000 0.000 0.994  ◎
# 2     岸＝信夫  自  自 0.979 0.003 0.001 0.012 0.005 0.000  ◎
# 3    畠中＝光成  維  維 0.000 0.006 0.994 0.000 0.000 0.000  ◎
# 4    佐々木＝紀  自  自 0.980 0.000 0.000 0.000 0.020 0.000  ◎
# 5    和泉＝信丈  共  共 0.000 0.003 0.000 0.000 0.000 0.997  ◎
# 6    西村＝真悟  次  次 0.040 0.001 0.001 0.000 0.958 0.000  ◎
# 7    江崎＝鉄磨  自  自 0.471 0.149 0.219 0.135 0.023 0.005  ◎
# 8    小里＝泰弘  自  自 0.960 0.005 0.000 0.032 0.003 0.000  ◎
# 9     簗＝和生  自  自 0.881 0.037 0.037 0.003 0.042 0.000  ◎
# 10    古賀＝誠  共  共 0.000 0.010 0.000 0.000 0.000 0.989  ◎
# 11  鎌田＝さゆり  民  民 0.000 0.936 0.014 0.004 0.000 0.045  ◎
# 12   丸山＝穂高  維  維 0.016 0.161 0.753 0.000 0.070 0.000  ◎
# 13    福井＝照  自  民 0.003 0.984 0.010 0.003 0.000 0.000
# 14  五十嵐＝雅之  公  公 0.131 0.059 0.002 0.805 0.002 0.001  ◎
# 15   前川＝忠夫  民  民 0.000 0.946 0.034 0.003 0.000 0.017  ◎
# 16   太田＝昭宏  公  公 0.018 0.000 0.000 0.982 0.000 0.000  ◎
# 17   下田＝彰一  自  自 0.993 0.000 0.000 0.000 0.006 0.000  ◎
# 18   塩崎＝恭久  自  自 0.940 0.004 0.000 0.053 0.003 0.000  ◎
# 19  萩生田＝光一  自  自 0.948 0.014 0.001 0.029 0.008 0.000  ◎
# 20   田島＝一成  民  民 0.000 0.934 0.064 0.000 0.000 0.001  ◎
# 21  小宮山＝泰子  民  民 0.000 0.588 0.412 0.000 0.000 0.001  ◎
# 22   中野渡＝旬  共  共 0.000 0.006 0.000 0.000 0.000 0.993  ◎
# 23   袴田＝富治  共  共 0.000 0.007 0.000 0.000 0.000 0.992  ◎
# 24  青山＝明日香  民  民 0.003 0.971 0.015 0.011 0.000 0.000  ◎
# 25    森＝英介  自  自 0.997 0.000 0.000 0.002 0.001 0.000  ◎
# 26    平＝善彦  共  共 0.000 0.008 0.000 0.000 0.000 0.991  ◎
# 27    泉＝幸親  自  自 0.576 0.057 0.008 0.355 0.004 0.000  ◎
# 28   角田＝秀穂  公  公 0.012 0.006 0.000 0.982 0.000 0.000  ◎
# 29  高栖＝留美子  自  自 0.937 0.001 0.001 0.000 0.061 0.000  ◎
# 30   中谷＝一馬  民  民 0.000 0.795 0.204 0.000 0.000 0.000  ◎
# 31   藤岡＝隆雄  民  維 0.000 0.014 0.983 0.000 0.002 0.000
# 32   竹本＝直一  自  自 0.988 0.004 0.001 0.001 0.006 0.000  ◎
# 33   安田＝庄一  次  自 0.910 0.000 0.000 0.000 0.090 0.000
# 34   中本＝太衛  次  維 0.029 0.454 0.499 0.000 0.018 0.000
# 35   苗村＝光雄  共  共 0.000 0.015 0.000 0.000 0.000 0.985  ◎
# 36   国重＝秀明  共  共 0.000 0.019 0.000 0.000 0.000 0.980  ◎
# 37    渡部＝結  共  共 0.000 0.014 0.000 0.000 0.000 0.986  ◎
# 38   井川＝泰雄  公  公 0.026 0.000 0.000 0.974 0.000 0.000  ◎
# 39    土井＝亨  自  自 0.798 0.130 0.030 0.013 0.030 0.000  ◎
# 40   明石＝行夫  共  共 0.000 0.004 0.000 0.000 0.000 0.996  ◎
# 41   亀岡＝偉民  自  自 0.587 0.342 0.005 0.062 0.005 0.000  ◎
# 42   山花＝郁夫  民  民 0.000 0.630 0.001 0.013 0.000 0.357  ◎
# 43    福山＝守  自  自 0.993 0.001 0.000 0.005 0.001 0.000  ◎
# 44    菅＝直人  民  民 0.000 0.962 0.033 0.000 0.000 0.004  ◎
# 45  熊木＝美奈子  民  民 0.000 0.913 0.082 0.000 0.000 0.004  ◎
# 46    山本＝拓  自  自 0.939 0.013 0.006 0.026 0.015 0.000  ◎
# 47  垣田＝千恵子  共  共 0.000 0.060 0.000 0.001 0.000 0.939  ◎
# 48   矢崎＝公二  民  民 0.000 0.957 0.004 0.003 0.000 0.036  ◎
# 49   吉良＝州司  民  自 0.482 0.269 0.196 0.003 0.049 0.000
# 50   吉田＝幸一  共  共 0.000 0.004 0.000 0.000 0.000 0.996  ◎
# 51   井上＝義久  公  公 0.031 0.003 0.000 0.966 0.000 0.000  ◎
# 52    岸＝武志  共  共 0.000 0.007 0.000 0.000 0.000 0.993  ◎
# 53   井上＝英孝  維  維 0.000 0.011 0.989 0.000 0.000 0.000  ◎
# 54   逢坂＝誠二  民  民 0.000 0.967 0.031 0.001 0.000 0.001  ◎
# 55   木村＝賢治  共  共 0.000 0.029 0.000 0.001 0.000 0.969  ◎
# 56    谷畑＝孝  維  維 0.002 0.228 0.769 0.000 0.001 0.000  ◎
# 57   中村＝裕之  自  自 0.937 0.006 0.003 0.001 0.054 0.000  ◎
# 58   三輪＝由美  共  共 0.000 0.009 0.000 0.000 0.000 0.991  ◎
# 59   矢崎＝勝己  共  共 0.000 0.011 0.000 0.000 0.000 0.989  ◎
# 60   平沢＝勝栄  自  自 0.958 0.012 0.005 0.004 0.021 0.000  ◎
# 61   橋本＝英教  自  自 0.974 0.001 0.000 0.025 0.001 0.000  ◎
# 62   藤田＝大助  民  民 0.000 0.886 0.114 0.000 0.000 0.000  ◎
# 63   松野＝博一  自  自 0.994 0.001 0.000 0.002 0.003 0.000  ◎
# 64   松浪＝健太  維  維 0.094 0.046 0.487 0.000 0.374 0.000  ◎
# 65   原＝矢寸久  共  共 0.000 0.019 0.000 0.000 0.000 0.980  ◎
# 66   中野＝洋昌  公  公 0.049 0.155 0.001 0.793 0.000 0.002  ◎
# 67  西銘＝恒三郎  自  自 0.795 0.053 0.007 0.138 0.007 0.000  ◎
# 68   井戸＝正枝  民  民 0.000 0.972 0.004 0.003 0.000 0.021  ◎
# 69  三ツ矢＝憲生  自  自 0.883 0.017 0.000 0.099 0.001 0.000  ◎
# 70  田中＝和加子  共  共 0.000 0.007 0.000 0.000 0.000 0.992  ◎
# 71   工藤＝彰三  自  自 0.972 0.003 0.003 0.000 0.023 0.000  ◎
# 72   伊佐＝進一  公  公 0.081 0.002 0.000 0.916 0.000 0.000  ◎
# 73   平岡＝秀夫  民  民 0.000 0.936 0.001 0.028 0.000 0.035  ◎
# 74   大西＝英男  自  自 0.912 0.004 0.002 0.002 0.081 0.000  ◎
# 75    秋元＝司  自  自 0.924 0.032 0.020 0.008 0.017 0.000  ◎
# 76   三木＝圭恵  維  維 0.017 0.017 0.917 0.000 0.049 0.000  ◎
# 77    吉俣＝洋  共  共 0.000 0.017 0.000 0.000 0.000 0.982  ◎
# 78   石井＝美鈴  共  共 0.000 0.008 0.000 0.000 0.000 0.992  ◎
# 79  池田＝真理子  共  共 0.000 0.011 0.000 0.000 0.000 0.989  ◎
# 80   奥野＝信亮  自  自 0.954 0.001 0.001 0.000 0.045 0.000  ◎
# 81   西村＝明宏  自  自 0.869 0.035 0.041 0.003 0.052 0.000  ◎
# 82    今＝秀子  共  共 0.000 0.008 0.000 0.000 0.000 0.992  ◎
# 83   橋本＝清仁  民  民 0.000 0.950 0.049 0.000 0.000 0.001  ◎
# 84   松村＝亮佑  共  共 0.000 0.013 0.000 0.000 0.000 0.987  ◎
# 85  上野＝賢一郎  自  自 0.759 0.156 0.056 0.007 0.021 0.000  ◎
# 86   田村＝貴昭  共  共 0.000 0.010 0.000 0.000 0.000 0.990  ◎
# 87   垣内＝雄一  共  共 0.000 0.012 0.000 0.000 0.000 0.988  ◎
# 88   平井＝卓也  自  自 0.985 0.002 0.001 0.001 0.012 0.000  ◎
# 89    篠原＝豪  維  維 0.000 0.011 0.989 0.000 0.000 0.000  ◎
# 90    中田＝宏  次  次 0.007 0.004 0.254 0.000 0.736 0.000  ◎
# 91   服部＝頼義  共  共 0.000 0.009 0.000 0.000 0.000 0.990  ◎
# 92    大見＝正  自  自 0.953 0.001 0.001 0.000 0.046 0.000  ◎
# 93   渡辺＝博道  自  自 0.971 0.001 0.000 0.025 0.003 0.000  ◎
# 94   藤田＝一枝  民  民 0.000 0.763 0.001 0.009 0.000 0.227  ◎
# 95   井出＝庸生  維  民 0.000 0.828 0.152 0.000 0.000 0.020
# 96  村上＝誠一郎  自  民 0.013 0.974 0.010 0.002 0.000 0.000
# 97   原田＝和広  民  民 0.000 0.948 0.051 0.000 0.000 0.000  ◎
# 98   増元＝照明  次  次 0.007 0.003 0.131 0.000 0.859 0.000  ◎
# 99    木原＝稔  自  自 0.962 0.002 0.001 0.001 0.035 0.000  ◎

# %%
print('F値: %f' % f1_score(np.argmax(test_y, 1), np.argmax(pred_y, 1), average='macro'))
# Out:
# F値: 0.897750
